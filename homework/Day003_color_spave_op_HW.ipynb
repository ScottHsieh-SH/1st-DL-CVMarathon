# %%
#bgr做直方均化
import cv2
import numpy as np
img_path = "D:\opcv\lena.png"

# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
# 以灰階圖片的方式載入
img_gray = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)


#BGR,G&R=0
b = img.copy()
b[:, :, 1] = 0
b[:, :, 2] = 0

#BGR,B&R=0
g = img.copy()
g[:, :, 0] = 0
g[:, :, 2] = 0

#BGR,B&G=0
r = img.copy()
r[:, :, 1] = 0
r[:, :, 0] = 0

#each channel do hist equalize
img_b = cv2.equalizeHist(img[:, :, 0])
img_g = cv2.equalizeHist(img[:, :, 1])
img_r = cv2.equalizeHist(img[:, :, 2])

imggg = img.copy()
#combime each channel
imggg[:, :, 0] = img_b
imggg[:, :, 1] = img_g
imggg[:, :, 2] = img_r

img_contrast_light = np.hstack((img_b,img_g, img_r))

while True:
    # 比較灰階圖片是否有做直方圖均衡的差異
   # cv2.imshow('equal histogram', img_contrast_light)
    cv2.imshow('imggg',imggg)
    cv2.imshow('img',img)
    k = cv2.waitKey(0)
    if k == 27:
        cv2.destroyAllWindows()
        break

# %%
#hsv做s的直方均化
import cv2
import numpy as np
img_path = "D:\opcv\lena.png"

# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
# 以灰階圖片的方式載入
img_gray = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img_s = cv2.equalizeHist(img_hsv[..., 1])
img_hsv[..., 1]=img_s
img_1 = cv2.cvtColor(img_hsv, cv2.COLOR_HSV2BGR)

while True:
    cv2.imshow('img',img)
    cv2.imshow('img_hsv',img_1)

    k = cv2.waitKey(0)
    if k == 27:
        cv2.destroyAllWindows()
        break

# %%
#hsv做改變飽和度
import cv2
import numpy as np
img_path = 'D:\opcv\lena.png'

# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
# 以灰階圖片的方式載入
img_gray = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)



img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
change_percentage = 0.2

# 針對飽和度的值做改變，超過界線 0~1 的都會 bound
# 在 HLS color space 減少飽和度
img_hsv_down=img_hsv.astype('float32')
img_hsv_down[..., 1] = img_hsv_down[..., 1]/255 - change_percentage
img_hsv_down[img_hsv_down[..., 1] < 0] = 0
img_hsv_down[..., 1] = img_hsv_down[..., 1]*255
img_hsv_down = img_hsv_down.astype('uint8')


# 在 HLS color space 增加飽和度
img_hsv_up = img_hsv.astype('float32')
img_hsv_up[..., 1] = img_hsv_up[..., 1]/255 + change_percentage
img_hsv_up[img_hsv_up[..., 1] > 1] = 1
img_hsv_up[..., 1] = img_hsv_up[..., 1]*255
img_hsv_up = img_hsv_up.astype('uint8')

# 轉換
img_hsv_down = cv2.cvtColor(img_hsv_down, cv2.COLOR_HSV2BGR)
img_hsv_up = cv2.cvtColor(img_hsv_up, cv2.COLOR_HSV2BGR)

# 組合圖片 + 顯示圖片
img_hsv_change = np.hstack((img, img_hsv_down, img_hsv_up))
while True:
    cv2.imshow('change saturation', img_hsv_change)
    
    k = cv2.waitKey(0)
    if k == 27:
        cv2.destroyAllWindows()
        break

# %%
bgr做方程式直接調整飽和度亮度
import cv2
import numpy as np
img_path = 'D:\opcv\lena.png'

# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
# 以灰階圖片的方式載入
img_gray = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# alpha: 控制對比度 (1.0~3.0)
# beta: 控制明亮度 (0~255)
add_contrast = cv2.convertScaleAbs(img,alpha=1.4,beta=0)
add_lighness = cv2.convertScaleAbs(img,alpha=1,beta=70)

# 組合圖片 + 顯示圖片
img_contrast_light = np.hstack((img, add_contrast, add_lighness))
while True:
    # 比較不同程度的對比 / 明亮
    cv2.imshow('adjust contrast and brighness', img_contrast_light)
    k = cv2.waitKey(0)
    if k == 27:
        cv2.destroyAllWindows()
        break
